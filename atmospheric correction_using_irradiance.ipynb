# %%
import numpy as np
import matplotlib as plt
from osgeo import gdal
import pandas as pd
import os

# %%
wavelen_dict={6:43300.0,10:28200.0,18:16000.0,36:8200.0,89:3400.0}

corr=pd.read_csv(r"E:LUT_OUTPUT/North_east_JUNE_1_10.csv")
# remove 23GHZ(12600um)
corr=corr[corr['wavelen_um']!=12600]
corr['UP_Irrad_BT(K)']=1.207*corr['UP_TOA_irradiance']*(corr['wavelen_um'])**4
corr['DOWN_Irrad_BT(K)']=1.207*corr['DOWN_TOA_irradiance']*(corr['wavelen_um'])**4
corr
# Out:
#     Unnamed: 0  DOY  wavelen_um  Transmissivity  Upwelling_BT(K)  \
# 0            0   10      3400.0        0.692064          62.6690
# 1            1   10      8200.0        0.707603         156.0130
# 3            3   10     16000.0        0.920671          31.4334
# 4            4   10     28200.0        0.937878          21.7138
# 5            5   10     43300.0        0.941592          20.8122
# 6            6    1      3400.0        0.692064          62.6690
# 7            7    1      8200.0        0.707603         156.0130
# 9            9    1     16000.0        0.920671          31.4334
# 10          10    1     28200.0        0.937878          21.7138
# 11          11    1     43300.0        0.941592          20.8122
# 12          12    2      3400.0        0.692064          62.6690
# 13          13    2      8200.0        0.707603         156.0130
# 15          15    2     16000.0        0.920671          31.4334
# 16          16    2     28200.0        0.937878          21.7138
# 17          17    2     43300.0        0.941592          20.8122
# 18          18    3      3400.0        0.692064          62.6690
# 19          19    3      8200.0        0.707603         156.0130
# 21          21    3     16000.0        0.920671          31.4334
# 22          22    3     28200.0        0.937878          21.7138
# 23          23    3     43300.0        0.941592          20.8122
# 24          24    4      3400.0        0.692064          62.6690
# 25          25    4      8200.0        0.707603         156.0130
# 27          27    4     16000.0        0.920671          31.4334
# 28          28    4     28200.0        0.937878          21.7138
# 29          29    4     43300.0        0.941592          20.8122
# 30          30    5      3400.0        0.692064          62.6690
# 31          31    5      8200.0        0.707603         156.0130
# 33          33    5     16000.0        0.920671          31.4334
# 34          34    5     28200.0        0.937878          21.7138
# 35          35    5     43300.0        0.941592          20.8122
# 36          36    6      3400.0        0.692064          62.6690
# 37          37    6      8200.0        0.707603         156.0130
# 39          39    6     16000.0        0.920671          31.4334
# 40          40    6     28200.0        0.937878          21.7138
# 41          41    6     43300.0        0.941592          20.8122
# 42          42    7      3400.0        0.692064          62.6690
# 43          43    7      8200.0        0.707603         156.0130
# 45          45    7     16000.0        0.920671          31.4334
# 46          46    7     28200.0        0.937878          21.7138
# 47          47    7     43300.0        0.941592          20.8122
# 48          48    8      3400.0        0.692064          62.6690
# 49          49    8      8200.0        0.707603         156.0130
# 51          51    8     16000.0        0.920671          31.4334
# 52          52    8     28200.0        0.937878          21.7138
# 53          53    8     43300.0        0.941592          20.8122
# 54          54    9      3400.0        0.692064          62.6690
# 55          55    9      8200.0        0.707603         156.0130
# 57          57    9     16000.0        0.920671          31.4334
# 58          58    9     28200.0        0.937878          21.7138
# 59          59    9     43300.0        0.941592          20.8122
#
#     Downwelling_BT(K)   UP_radiance  UP_TOA_irradiance  DOWN_radiance  \
# 0             72.6199  5.311880e-13       4.365050e-15   6.184900e-13
# 1            193.6840  4.023390e-14       1.330720e-16   5.000460e-14
# 3             35.0340  5.542940e-16       9.408630e-18   6.187180e-16
# 4             24.2554  3.978380e-17       1.010560e-18   4.449660e-17
# 5             23.2796  6.886620e-18       1.965620e-19   7.709730e-18
# 6             72.6199  5.311880e-13       4.365050e-15   6.184900e-13
# 7            193.6840  4.023390e-14       1.330720e-16   5.000460e-14
# 9             35.0340  5.542940e-16       9.408630e-18   6.187180e-16
# 10            24.2554  3.978380e-17       1.010560e-18   4.449660e-17
# 11            23.2796  6.886620e-18       1.965620e-19   7.709730e-18
# 12            72.6199  5.311880e-13       4.365050e-15   6.184900e-13
# 13           193.6840  4.023390e-14       1.330720e-16   5.000460e-14
# 15            35.0340  5.542940e-16       9.408630e-18   6.187180e-16
# 16            24.2554  3.978380e-17       1.010560e-18   4.449660e-17
# 17            23.2796  6.886620e-18       1.965620e-19   7.709730e-18
# 18            72.6199  5.311880e-13       4.365050e-15   6.184900e-13
# 19           193.6840  4.023390e-14       1.330720e-16   5.000460e-14
# 21            35.0340  5.542940e-16       9.408630e-18   6.187180e-16
# 22            24.2554  3.978380e-17       1.010560e-18   4.449660e-17
# 23            23.2796  6.886620e-18       1.965620e-19   7.709730e-18
# 24            72.6199  5.311880e-13       4.365050e-15   6.184900e-13
# 25           193.6840  4.023390e-14       1.330720e-16   5.000460e-14
# 27            35.0340  5.542940e-16       9.408630e-18   6.187180e-16
# 28            24.2554  3.978380e-17       1.010560e-18   4.449660e-17
# 29            23.2796  6.886620e-18       1.965620e-19   7.709730e-18
# 30            72.6199  5.311880e-13       4.365050e-15   6.184900e-13
# 31           193.6840  4.023390e-14       1.330720e-16   5.000460e-14
# 33            35.0340  5.542940e-16       9.408630e-18   6.187180e-16
# 34            24.2554  3.978380e-17       1.010560e-18   4.449660e-17
# 35            23.2796  6.886620e-18       1.965620e-19   7.709730e-18
# 36            72.6199  5.311880e-13       4.365050e-15   6.184900e-13
# 37           193.6840  4.023390e-14       1.330720e-16   5.000460e-14
# 39            35.0340  5.542940e-16       9.408630e-18   6.187180e-16
# 40            24.2554  3.978380e-17       1.010560e-18   4.449660e-17
# 41            23.2796  6.886620e-18       1.965620e-19   7.709730e-18
# 42            72.6199  5.311880e-13       4.365050e-15   6.184900e-13
# 43           193.6840  4.023390e-14       1.330720e-16   5.000460e-14
# 45            35.0340  5.542940e-16       9.408630e-18   6.187180e-16
# 46            24.2554  3.978380e-17       1.010560e-18   4.449660e-17
# 47            23.2796  6.886620e-18       1.965620e-19   7.709730e-18
# 48            72.6199  5.311880e-13       4.365050e-15   6.184900e-13
# 49           193.6840  4.023390e-14       1.330720e-16   5.000460e-14
# 51            35.0340  5.542940e-16       9.408630e-18   6.187180e-16
# 52            24.2554  3.978380e-17       1.010560e-18   4.449660e-17
# 53            23.2796  6.886620e-18       1.965620e-19   7.709730e-18
# 54            72.6199  5.311880e-13       4.365050e-15   6.184900e-13
# 55           193.6840  4.023390e-14       1.330720e-16   5.000460e-14
# 57            35.0340  5.542940e-16       9.408630e-18   6.187180e-16
# 58            24.2554  3.978380e-17       1.010560e-18   4.449660e-17
# 59            23.2796  6.886620e-18       1.965620e-19   7.709730e-18
#
#     DOWN_TOA_irradiance  UP_Irrad_BT(K)  DOWN_Irrad_BT(K)
# 0          4.210210e-15        0.704064          0.679089
# 1          1.283510e-16        0.726188          0.700425
# 3          9.074870e-18        0.744241          0.717840
# 4          9.747120e-19        0.771375          0.744012
# 5          1.895890e-19        0.833985          0.804400
# 6          4.210210e-15        0.704064          0.679089
# 7          1.283510e-16        0.726188          0.700425
# 9          9.074870e-18        0.744241          0.717840
# 10         9.747120e-19        0.771375          0.744012
# 11         1.895890e-19        0.833985          0.804400
# 12         4.210210e-15        0.704064          0.679089
# 13         1.283510e-16        0.726188          0.700425
# 15         9.074870e-18        0.744241          0.717840
# 16         9.747120e-19        0.771375          0.744012
# 17         1.895890e-19        0.833985          0.804400
# 18         4.210210e-15        0.704064          0.679089
# 19         1.283510e-16        0.726188          0.700425
# 21         9.074870e-18        0.744241          0.717840
# 22         9.747120e-19        0.771375          0.744012
# 23         1.895890e-19        0.833985          0.804400
# 24         4.210210e-15        0.704064          0.679089
# 25         1.283510e-16        0.726188          0.700425
# 27         9.074870e-18        0.744241          0.717840
# 28         9.747120e-19        0.771375          0.744012
# 29         1.895890e-19        0.833985          0.804400
# 30         4.210210e-15        0.704064          0.679089
# 31         1.283510e-16        0.726188          0.700425
# 33         9.074870e-18        0.744241          0.717840
# 34         9.747120e-19        0.771375          0.744012
# 35         1.895890e-19        0.833985          0.804400
# 36         4.210210e-15        0.704064          0.679089
# 37         1.283510e-16        0.726188          0.700425
# 39         9.074870e-18        0.744241          0.717840
# 40         9.747120e-19        0.771375          0.744012
# 41         1.895890e-19        0.833985          0.804400
# 42         4.210210e-15        0.704064          0.679089
# 43         1.283510e-16        0.726188          0.700425
# 45         9.074870e-18        0.744241          0.717840
# 46         9.747120e-19        0.771375          0.744012
# 47         1.895890e-19        0.833985          0.804400
# 48         4.210210e-15        0.704064          0.679089
# 49         1.283510e-16        0.726188          0.700425
# 51         9.074870e-18        0.744241          0.717840
# 52         9.747120e-19        0.771375          0.744012
# 53         1.895890e-19        0.833985          0.804400
# 54         4.210210e-15        0.704064          0.679089
# 55         1.283510e-16        0.726188          0.700425
# 57         9.074870e-18        0.744241          0.717840
# 58         9.747120e-19        0.771375          0.744012
# 59         1.895890e-19        0.833985          0.804400

# %%
LST_path=r'E:23sept/LST/june_LST/'
lst_dict={}
LST_list=[]
doy_num=151
for root, dirs, files in os.walk(LST_path):
    for name in files:
        LST_list.append(LST_path+name)
for i in range(len(LST_list)):
    lst_dict[i+1+doy_num]=LST_list[i]
   

emiss_path = r'E:23sept/Emissivity/june_emiss/'
emiss_dict={}
for root, dirs, files in os.walk(emiss_path):
    for name in files:
        if 'V.tif' in name:
            W=int(name[35:37].strip('.'))
#             emiss_list.append(emiss_path+name)
            emiss_dict[W]=emiss_path+name

# %%
print(lst_dict,'\n')
print(emiss_dict)
# Out:
# {152: 'E:23sept/LST/june_LST/MYD11C1.A2006152.006.2015292174138.hdf.tif.tif', 153: 'E:23sept/LST/june_LST/MYD11C1.A2006153.006.2015292142521.hdf.tif.tif', 154: 'E:23sept/LST/june_LST/MYD11C1.A2006154.006.2015292142544.hdf.tif.tif', 155: 'E:23sept/LST/june_LST/MYD11C1.A2006155.006.2015292142520.hdf.tif.tif', 156: 'E:23sept/LST/june_LST/MYD11C1.A2006156.006.2015292142522.hdf.tif.tif', 157: 'E:23sept/LST/june_LST/MYD11C1.A2006157.006.2015292142525.hdf.tif.tif', 158: 'E:23sept/LST/june_LST/MYD11C1.A2006158.006.2015292152053.hdf.tif.tif', 159: 'E:23sept/LST/june_LST/MYD11C1.A2006159.006.2015292174142.hdf.tif.tif', 160: 'E:23sept/LST/june_LST/MYD11C1.A2006160.006.2015292174142.hdf.tif.tif', 161: 'E:23sept/LST/june_LST/MYD11C1.A2006161.006.2015292184846.hdf.tif.tif'}
#
# {10: 'E:23sept/Emissivity/june_emiss/AMSER-E_monthly_emissivity_June200610.7 V.tif.tif', 18: 'E:23sept/Emissivity/june_emiss/AMSER-E_monthly_emissivity_June200618.7 V.tif.tif', 36: 'E:23sept/Emissivity/june_emiss/AMSER-E_monthly_emissivity_June200636.5 V.tif.tif', 6: 'E:23sept/Emissivity/june_emiss/AMSER-E_monthly_emissivity_June20066.9  V.tif.tif', 89: 'E:23sept/Emissivity/june_emiss/AMSER-E_monthly_emissivity_June200689.0 V.tif.tif'}

# %%
LST_error_path=r'E:/23sept/Irradiance_LST_error/'

# %%
def WriteImage(outpath,image,proj,geo):
    ds=None
    driver=gdal.GetDriverByName("GTiff")
    ds=driver.Create(outpath,image.shape[1],image.shape[0], 1,gdal.GDT_Float32)
    ds.SetProjection(proj)
    ds.SetGeoTransform(geo)
    ds.GetRasterBand(1).WriteArray(image)
    return ds

# %%
BT_path=r"E:23sept/Resampled_BT_clipped/april_BT//"
for root, dirs, files in os.walk(BT_path):
    for name in files:
        if ('V_Res_1' in name) or ('89_0V_Res_4' in name):
            BTfilePath=BT_path+name
            print(name)
            BT_DOY=int(name[30:32])+doy_num
            print(BT_DOY)
            wavelen=int(name[57:59])
            print(wavelen)
# Out:
# AMSR_E_L3_DailyLand_V06_20060401_Ascending_Land_Grid_A_TB06_9V_Res_1_5a345a8f.tif.tif
# 152
# 6
# AMSR_E_L3_DailyLand_V06_20060401_Ascending_Land_Grid_A_TB10_7V_Res_1_5a345a8f.tif.tif
# 152
# 10
# AMSR_E_L3_DailyLand_V06_20060401_Ascending_Land_Grid_A_TB18_7V_Res_1_5a345a8f.tif.tif
# 152
# 18
# AMSR_E_L3_DailyLand_V06_20060401_Ascending_Land_Grid_A_TB36_5V_Res_1_5a345a8f.tif.tif
# 152
# 36
# AMSR_E_L3_DailyLand_V06_20060401_Ascending_Land_Grid_A_TB89_0V_Res_4_5a345a8f.tif.tif
# 152
# 89
# AMSR_E_L3_DailyLand_V06_20060402_Ascending_Land_Grid_A_TB06_9V_Res_1_5a3ec79e.tif.tif
# 153
# 6
# AMSR_E_L3_DailyLand_V06_20060402_Ascending_Land_Grid_A_TB10_7V_Res_1_5a3ec79e.tif.tif
# 153
# 10
# AMSR_E_L3_DailyLand_V06_20060402_Ascending_Land_Grid_A_TB18_7V_Res_1_5a3ec79e.tif.tif
# 153
# 18
# AMSR_E_L3_DailyLand_V06_20060402_Ascending_Land_Grid_A_TB36_5V_Res_1_5a3ec79e.tif.tif
# 153
# 36
# AMSR_E_L3_DailyLand_V06_20060402_Ascending_Land_Grid_A_TB89_0V_Res_4_5a3ec79e.tif.tif
# 153
# 89
# AMSR_E_L3_DailyLand_V06_20060403_Ascending_Land_Grid_A_TB06_9V_Res_1_5a3ecf3c.tif.tif
# 154
# 6
# AMSR_E_L3_DailyLand_V06_20060403_Ascending_Land_Grid_A_TB10_7V_Res_1_5a3ecf3c.tif.tif
# 154
# 10
# AMSR_E_L3_DailyLand_V06_20060403_Ascending_Land_Grid_A_TB18_7V_Res_1_5a3ecf3c.tif.tif
# 154
# 18
# AMSR_E_L3_DailyLand_V06_20060403_Ascending_Land_Grid_A_TB36_5V_Res_1_5a3ecf3c.tif.tif
# 154
# 36
# AMSR_E_L3_DailyLand_V06_20060403_Ascending_Land_Grid_A_TB89_0V_Res_4_5a3ecf3c.tif.tif
# 154
# 89
# AMSR_E_L3_DailyLand_V06_20060404_Ascending_Land_Grid_A_TB06_9V_Res_1_5a3ed034.tif.tif
# 155
# 6
# AMSR_E_L3_DailyLand_V06_20060404_Ascending_Land_Grid_A_TB10_7V_Res_1_5a3ed034.tif.tif
# 155
# 10
# AMSR_E_L3_DailyLand_V06_20060404_Ascending_Land_Grid_A_TB18_7V_Res_1_5a3ed034.tif.tif
# 155
# 18
# AMSR_E_L3_DailyLand_V06_20060404_Ascending_Land_Grid_A_TB36_5V_Res_1_5a3ed034.tif.tif
# 155
# 36
# AMSR_E_L3_DailyLand_V06_20060404_Ascending_Land_Grid_A_TB89_0V_Res_4_5a3ed034.tif.tif
# 155
# 89
# AMSR_E_L3_DailyLand_V06_20060405_Ascending_Land_Grid_A_TB06_9V_Res_1_5a3ecfdb.tif.tif
# 156
# 6
# AMSR_E_L3_DailyLand_V06_20060405_Ascending_Land_Grid_A_TB10_7V_Res_1_5a3ecfdb.tif.tif
# 156
# 10
# AMSR_E_L3_DailyLand_V06_20060405_Ascending_Land_Grid_A_TB18_7V_Res_1_5a3ecfdb.tif.tif
# 156
# 18
# AMSR_E_L3_DailyLand_V06_20060405_Ascending_Land_Grid_A_TB36_5V_Res_1_5a3ecfdb.tif.tif
# 156
# 36
# AMSR_E_L3_DailyLand_V06_20060405_Ascending_Land_Grid_A_TB89_0V_Res_4_5a3ecfdb.tif.tif
# 156
# 89
# AMSR_E_L3_DailyLand_V06_20060406_Ascending_Land_Grid_A_TB06_9V_Res_1_5a3f2590.tif.tif
# 157
# 6
# AMSR_E_L3_DailyLand_V06_20060406_Ascending_Land_Grid_A_TB10_7V_Res_1_5a3f2590.tif.tif
# 157
# 10
# AMSR_E_L3_DailyLand_V06_20060406_Ascending_Land_Grid_A_TB18_7V_Res_1_5a3f2590.tif.tif
# 157
# 18
# AMSR_E_L3_DailyLand_V06_20060406_Ascending_Land_Grid_A_TB36_5V_Res_1_5a3f2590.tif.tif
# 157
# 36
# AMSR_E_L3_DailyLand_V06_20060406_Ascending_Land_Grid_A_TB89_0V_Res_4_5a3f2590.tif.tif
# 157
# 89
# AMSR_E_L3_DailyLand_V06_20060407_Ascending_Land_Grid_A_TB06_9V_Res_1_5a3f2995.tif.tif
# 158
# 6
# AMSR_E_L3_DailyLand_V06_20060407_Ascending_Land_Grid_A_TB10_7V_Res_1_5a3f2995.tif.tif
# 158
# 10
# AMSR_E_L3_DailyLand_V06_20060407_Ascending_Land_Grid_A_TB18_7V_Res_1_5a3f2995.tif.tif
# 158
# 18
# AMSR_E_L3_DailyLand_V06_20060407_Ascending_Land_Grid_A_TB36_5V_Res_1_5a3f2995.tif.tif
# 158
# 36
# AMSR_E_L3_DailyLand_V06_20060407_Ascending_Land_Grid_A_TB89_0V_Res_4_5a3f2995.tif.tif
# 158
# 89
# AMSR_E_L3_DailyLand_V06_20060408_Ascending_Land_Grid_A_TB06_9V_Res_1_5a3f2973.tif.tif
# 159
# 6
# AMSR_E_L3_DailyLand_V06_20060408_Ascending_Land_Grid_A_TB10_7V_Res_1_5a3f2973.tif.tif
# 159
# 10
# AMSR_E_L3_DailyLand_V06_20060408_Ascending_Land_Grid_A_TB18_7V_Res_1_5a3f2973.tif.tif
# 159
# 18
# AMSR_E_L3_DailyLand_V06_20060408_Ascending_Land_Grid_A_TB36_5V_Res_1_5a3f2973.tif.tif
# 159
# 36
# AMSR_E_L3_DailyLand_V06_20060408_Ascending_Land_Grid_A_TB89_0V_Res_4_5a3f2973.tif.tif
# 159
# 89
# AMSR_E_L3_DailyLand_V06_20060409_Ascending_Land_Grid_A_TB06_9V_Res_1_5a3f2a47.tif.tif
# 160
# 6
# AMSR_E_L3_DailyLand_V06_20060409_Ascending_Land_Grid_A_TB10_7V_Res_1_5a3f2a47.tif.tif
# 160
# 10
# AMSR_E_L3_DailyLand_V06_20060409_Ascending_Land_Grid_A_TB18_7V_Res_1_5a3f2a47.tif.tif
# 160
# 18
# AMSR_E_L3_DailyLand_V06_20060409_Ascending_Land_Grid_A_TB36_5V_Res_1_5a3f2a47.tif.tif
# 160
# 36
# AMSR_E_L3_DailyLand_V06_20060409_Ascending_Land_Grid_A_TB89_0V_Res_4_5a3f2a47.tif.tif
# 160
# 89
# AMSR_E_L3_DailyLand_V06_20060410_Ascending_Land_Grid_A_TB06_9V_Res_1_5a3f2ded.tif.tif
# 161
# 6
# AMSR_E_L3_DailyLand_V06_20060410_Ascending_Land_Grid_A_TB10_7V_Res_1_5a3f2ded.tif.tif
# 161
# 10
# AMSR_E_L3_DailyLand_V06_20060410_Ascending_Land_Grid_A_TB18_7V_Res_1_5a3f2ded.tif.tif
# 161
# 18
# AMSR_E_L3_DailyLand_V06_20060410_Ascending_Land_Grid_A_TB36_5V_Res_1_5a3f2ded.tif.tif
# 161
# 36
# AMSR_E_L3_DailyLand_V06_20060410_Ascending_Land_Grid_A_TB89_0V_Res_4_5a3f2ded.tif.tif
# 161
# 89

# %%
df=pd.DataFrame(columns=['DOY','Wavelenght','MODIS_LST','LST_corrected','LST_raw'])

# %%
# BT data
BT_path=r"E:23sept/Resampled_BT_clipped/june_BT//"
for root, dirs, files in os.walk(BT_path):
    for name in files:
        if ('V_Res_1' in name) or ('89_0V_Res_4' in name):
        
            BTfilePath=BT_path+name
#             print(BTfilePath)
#             BT_DOY=int(name[30:32])+90
            BT_DOY=int(name[30:32])
            wavelen=int(name[57:59])

#             print(wavelen)
            BT=gdal.Open(BTfilePath)
            proj=BT.GetProjection()
            geotrans=BT.GetGeoTransform()
            BT_raw=BT.ReadAsArray().astype("float64")
            
            new_df=corr[(corr['DOY']==BT_DOY) & (corr['wavelen_um']==wavelen_dict[wavelen])]
#             print(new_df)
#             upwell=np.array(new_df['Upwelling_BT(K)'])
#             downwell=np.array(new_df['Downwelling_BT(K)'])
            upwell=np.array(new_df['UP_Irrad_BT(K)'])
            downwell=np.array(new_df['DOWN_Irrad_BT(K)'])
            trans=np.array(new_df['Transmissivity'])
#             print(upwell,downwell,trans)
            emissFile=emiss_dict[wavelen]
            emiss=gdal.Open(emissFile)
            emiss=emiss.ReadAsArray().astype('float64')
            emiss[emiss<0.5]=np.nan
#             emiss[emiss>0.99999]=np.nan
            
            estimated_LST=(BT_raw-upwell-(1-emiss)*((downwell+2.725)*trans))/(emiss*trans)
            raw_BT_LST=BT_raw/emiss
            
            MOD_LSTpath=lst_dict[BT_DOY+doy_num]
            MOD_LST=gdal.Open(MOD_LSTpath)
            MOD_LST=MOD_LST.ReadAsArray().astype('float64')
            
            error=estimated_LST-MOD_LST
#             storeLST  in csv
            f=pd.DataFrame({})
            f['MODIS_LST']=(MOD_LST[44:55,58:69]).flatten()
            f['LST_corrected']=(estimated_LST[44:55,58:69]).flatten()
            f['LST_raw']=(raw_BT_LST[44:55,58:69]).flatten()
            f['DOY']=BT_DOY+doy_num
            f['Wavelenght']=wavelen
            
            df=df.append(f,ignore_index=True)
#             print(f)
            f=None            
#             outpath=LST_error_path+'LST_error_June_'+str(BT_DOY)+"_"+name[56:62]+'.tif'
#             VE=WriteImage(outpath,error,proj,geotrans)
            
#             VE=None

# %%
df.to_csv(r'E:23sept/Irradiance_Error_plot/North_east_June.csv')

# %%
len('AMSER-E_monthly_emissivity_April2006')
# Out:
# 36

# %%
df
# Out:
#       DOY   MODIS_LST  LST_corrected     LST_raw  Wavelenght
# 0     121  316.333984            NaN         NaN         6.0
# 1     121  316.747437            NaN         NaN         6.0
# 2     121  318.998016            NaN         NaN         6.0
# 3     121  318.735046            NaN         NaN         6.0
# 4     121  319.401794            NaN         NaN         6.0
# ...   ...         ...            ...         ...         ...
# 6045  130         NaN     297.302362  271.780621        89.0
# 6046  130         NaN     272.089086  254.419044        89.0
# 6047  130         NaN     304.438175  277.346819        89.0
# 6048  130         NaN            NaN         NaN        89.0
# 6049  130         NaN            NaN         NaN        89.0
#
# [6050 rows x 5 columns]

# %%
emiss_dict
# Out:
# {10: 'E:23sept/april_emiss/AMSER-E_monthly_emissivity_April200610.7 V.tif.tif',
#  18: 'E:23sept/april_emiss/AMSER-E_monthly_emissivity_April200618.7 V.tif.tif',
#  36: 'E:23sept/april_emiss/AMSER-E_monthly_emissivity_April200636.5 V.tif.tif',
#  6: 'E:23sept/april_emiss/AMSER-E_monthly_emissivity_April20066.9  V.tif.tif',
#  89: 'E:23sept/april_emiss/AMSER-E_monthly_emissivity_April200689.0 V.tif.tif'}

# %%
a=np.array([1,2,3])
b=np.array([2])
a-b
# Out:
# array([-1,  0,  1])
