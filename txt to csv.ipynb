# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'E:\MODTRAN\New folder\L7_upwell_new.csv',header=[4,5])[:222]
df.columns = df.columns.map('_'.join)
df.dropna() 
df=df.astype('float64')

# %%
df=df[(df['Freq_[cm-1]']>800.0) & (df['Freq_[cm-1]']<961.0)]
df
# Out:
#      Freq_[cm-1]    combin_  path trans    path_  emission  \
# 61         801.0               0.918905       4.587450e-07
# 62         802.0               0.874529       8.807560e-07
# 63         803.0               0.870578       9.180870e-07
# 64         804.0               0.919541       4.552340e-07
# 65         805.0               0.873886       8.862060e-07
# ..           ...                    ...                ...
# 216        956.0               0.865182       7.066460e-07
# 217        957.0               0.906925       3.981420e-07
# 218        958.0               0.879020       6.004590e-07
# 219        959.0               0.894514       4.839230e-07
# 220        960.0               0.908959       3.780710e-07
#
#        path thermal_   scat    surface_   emission    path multiple_   scat  \
# 61             4.843960e-07               0.000013             7.628970e-12
# 62             4.676670e-07               0.000012             6.812640e-12
# ...

# %%
df.mean(axis=0)
# Out:
# Freq_[cm-1]                 8.805000e+02
#   combin_  path trans       9.045861e-01
#   path_  emission           4.659821e-07
#   path thermal_   scat      5.096206e-07
#   surface_   emission       1.123589e-05
#   path multiple_   scat     1.457832e-11
#   sing_  scat               1.206255e-10
#   grnd_  rflt               0.000000e+00
#   drct_  rflt               0.000000e+00
#   total_   rad              1.221162e-05
#   irrad_   ref              1.510530e-07
#   irrad_  @obs              1.905593e-07
#   - nat log_  path trans    1.005574e-01
#   direct_  emiss            1.000000e+00
#   ToA_  irrad               1.905593e-07
#   bbody_  temp[K]           3.007865e+02
# dtype: float64
