# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'E:LUT_OUTPUT/North_east_APRIL_1_10.csv')
df
# Out:
#     Unnamed: 0  DOY  wavelen_um  Transmissivity  Upwelling_BT(K)  \
# 0            0   10      3400.0        0.685102          63.5541
# 1            1   10      8200.0        0.700549         156.4580
# 2            2   10     12600.0        0.893549          48.5516
# 3            3   10     16000.0        0.917370          32.1787
# 4            4   10     28200.0        0.935253          22.2556
# 5            5   10     43300.0        0.939116          21.3385
# 6            6    1      3400.0        0.685102          63.5541
# 7            7    1      8200.0        0.700549         156.4580
# 8            8    1     12600.0        0.893549          48.5516
# 9            9    1     16000.0        0.917370          32.1787
# 10          10    1     28200.0        0.935253          22.2556
# 11          11    1     43300.0        0.939116          21.3385
# 12          12    2      3400.0        0.685102          63.5541
# ...

# %%
df['UP_ratio']=df['UP_TOA_irradiance']/df['UP_radiance']
df['DOWN_ratio']=df['DOWN_TOA_irradiance']/df['DOWN_radiance']

# %%
df
# Out:
#     Unnamed: 0  DOY  wavelen_um  Transmissivity  Upwelling_BT(K)  \
# 0            0   10      3400.0        0.685102          63.5541
# 1            1   10      8200.0        0.700549         156.4580
# 2            2   10     12600.0        0.893549          48.5516
# 3            3   10     16000.0        0.917370          32.1787
# 4            4   10     28200.0        0.935253          22.2556
# 5            5   10     43300.0        0.939116          21.3385
# 6            6    1      3400.0        0.685102          63.5541
# 7            7    1      8200.0        0.700549         156.4580
# 8            8    1     12600.0        0.893549          48.5516
# 9            9    1     16000.0        0.917370          32.1787
# 10          10    1     28200.0        0.935253          22.2556
# 11          11    1     43300.0        0.939116          21.3385
# 12          12    2      3400.0        0.685102          63.5541
# ...

# %%
df['UP_Irrad_BT(K)']=1.207*df['UP_TOA_irradiance']*(df['wavelen_um'])**4
df['DOWN_Irrad_BT(K)']=1.207*df['DOWN_TOA_irradiance']*(df['wavelen_um'])**4

# %%
df
# Out:
#     Unnamed: 0  DOY  wavelen_um  Transmissivity  Upwelling_BT(K)  \
# 0            0   10      3400.0        0.685102          63.5541
# 1            1   10      8200.0        0.700549         156.4580
# 2            2   10     12600.0        0.893549          48.5516
# 3            3   10     16000.0        0.917370          32.1787
# 4            4   10     28200.0        0.935253          22.2556
# 5            5   10     43300.0        0.939116          21.3385
# 6            6    1      3400.0        0.685102          63.5541
# 7            7    1      8200.0        0.700549         156.4580
# 8            8    1     12600.0        0.893549          48.5516
# 9            9    1     16000.0        0.917370          32.1787
# 10          10    1     28200.0        0.935253          22.2556
# 11          11    1     43300.0        0.939116          21.3385
# 12          12    2      3400.0        0.685102          63.5541
# ...

# %%
df['UP_radiance_BT(K)']=3.791*df['UP_radiance']*(df['wavelen_um'])**4
df['DOWN_radiance_BT(K)']=3.791*df['DOWN_radiance']*(df['wavelen_um'])**4

# %%
df
# Out:
#     Unnamed: 0  DOY  wavelen_um  Transmissivity  Upwelling_BT(K)  \
# 0            0   10      3400.0        0.685102          63.5541
# 1            1   10      8200.0        0.700549         156.4580
# 2            2   10     12600.0        0.893549          48.5516
# 3            3   10     16000.0        0.917370          32.1787
# 4            4   10     28200.0        0.935253          22.2556
# 5            5   10     43300.0        0.939116          21.3385
# 6            6    1      3400.0        0.685102          63.5541
# 7            7    1      8200.0        0.700549         156.4580
# 8            8    1     12600.0        0.893549          48.5516
# 9            9    1     16000.0        0.917370          32.1787
# 10          10    1     28200.0        0.935253          22.2556
# 11          11    1     43300.0        0.939116          21.3385
# 12          12    2      3400.0        0.685102          63.5541
# ...
