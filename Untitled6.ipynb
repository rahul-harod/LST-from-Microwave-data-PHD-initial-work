# %%
import numpy as np
import matplotlib.pyplot as plt
from osgeo import gdal

# %%
data=gdal.Open(r"E:/rahul/MODIS_Resample_LST/ MYD11C1.A2006091.006.2015286220745.hdf.tif")
data=data.ReadAsArray()

# %%
plt.imshow(data)
plt.colorbar(label="Like/Dislike Ratio", orientation="horizontal")
plt.show()
