# %%
import os
import glob
import matplotlib.pyplot as plt
from osgeo import gdal
import numpy as np
import pandas as pd

# %%
path=r"E:\rahul\New folder"

# %%
i=0
for root, dirs, files in os.walk(path):
    for names in files:
        full_path=os.path.join(root,names)
        print(full_path)
        i+=1
        
#         p=gdal.Open(full_path)
#         subdata=p.GetSubDatasets()
#         for i in range(len(subdata)):
#             print(subdata[i][1])
print(i)
# Out:
# E:\rahul\New folder\31214692\AMSR_E_L3_DailyLand_V06_20060501_Ascending_Land_Grid_A_Inversion_QC_Flag_5a4025cc.tif
# E:\rahul\New folder\31214692\AMSR_E_L3_DailyLand_V06_20060501_Ascending_Land_Grid_A_Land_Surface_Temp_5a4025cc.tif
# E:\rahul\New folder\31214692\AMSR_E_L3_DailyLand_V06_20060501_Ascending_Land_Grid_A_Soil_Moisture_5a4025cc.tif
# E:\rahul\New folder\31214692\AMSR_E_L3_DailyLand_V06_20060501_Ascending_Land_Grid_A_TB06_9H_Res_1_5a4025cc.tif
# E:\rahul\New folder\31214692\AMSR_E_L3_DailyLand_V06_20060501_Ascending_Land_Grid_A_TB06_9V_Res_1_5a4025cc.tif
# E:\rahul\New folder\31214692\AMSR_E_L3_DailyLand_V06_20060501_Ascending_Land_Grid_A_TB10_7H_Res_1_5a4025cc.tif
# E:\rahul\New folder\31214692\AMSR_E_L3_DailyLand_V06_20060501_Ascending_Land_Grid_A_TB10_7V_Res_1_5a4025cc.tif
# E:\rahul\New folder\31214692\AMSR_E_L3_DailyLand_V06_20060501_Ascending_Land_Grid_A_TB18_7H_Res_1_5a4025cc.tif
# ...

# %%
# s=gdal.Open('HDF4_EOS:EOS_GRID:"E:/rahul/new_BT/AMSR_E_L3_DailyLand_V06_20060331.hdf":Descending_Land_Grid:"D_TB06.9V (Res 1)"')
# s.GetGeoTransform()

# %%
# p=gdal.Open('HDF4_EOS:EOS_GRID:"E:\\\\a\\MYD11C1.A2006091.006.2015286220745.hdf":MODIS_CMG_3MIN_LST:LST_Day_CMG')
# projection=p.GetProjection()
# geotrans=(-179.999999415, 0.25, 0.0, 86.716744081, 0.0, -0.25)
# print((projection))
# print(geotrans)

# %%
p=gdal.Open(r'E://rahul/brightness_temp/31209800\AMSR_E_L3_DailyLand_V06_20060401_Ascending_Land_Grid_A_TB18_7V_Res_1_5a345a8f.tif')
projection=p.GetProjection()
geotrans=p.GetGeoTransform()
print(projection)
print(geotrans)
# Out:
# GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# (-179.999999415, 0.26030368500858714, 0.0, 86.716744081, 0.0, -0.26030368500858714)

# %%
def WriteImage(outpath,image,proj,geo):
    ds=None
    driver=gdal.GetDriverByName("GTiff")
    ds=driver.Create(outpath,image.shape[1],image.shape[0], 1,gdal.GDT_Float32)
    ds.SetProjection(proj)
    ds.SetGeoTransform(geo)
    ds.GetRasterBand(1).WriteArray(image)
    return ds

# %%
s=gdal.Open(r"E:\rahul\Resampled_AMSER_E_BT\ AMSR_E_L3_DailyLand_V06_20060401_Ascending_Land_Grid_A_TB10_7H_Res_1_5a345a8f.tif.tif")
projection=s.GetProjection() 
geotrans=s.GetGeoTransform()
print(projection)
print(geotrans)
# Out:
# GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# (-179.999999415, 0.25, 0.0, 86.716744081, 0.0, -0.25)

# %%
# geotrans=(-180, 0.25, 0.0, 90, 0.0, -0.25)

# %%
for root, dirs, files in os.walk(path):
    for names in files:
        full_path=os.path.join(root,names)
        data=gdal.Open(full_path)
        data=data.ReadAsArray()
        path=r"E:\rahul\Resampled_AMSER_E_BT\ "
        output_path=path+ names +'.tif'
        VE=WriteImage(output_path,data,projection,geotrans)
#         t=gdal.Warp(output_path,VE,
#                     xRes=0.25,yRes=0.25,
#                     resampleAlg=gdal.GRA_Average
#                     )
#         for i in range(len(subdata)):
#             data=gdal.Open(subdata[i][0])
#             data=data.ReadAsArray()
#             path=r"E:\rahul\Resampled_AMSER_E_BT"
#             output_res=path +'\_'+ names[24:32] + subdata[i][1][11:]+ '.tif'
#             print(output_res)
#             VE=WriteImage(path+'proj.tif',data,projection,geotrans)
#             t=gdal.Warp(output_res,VE,
#                          xRes=0.25,yRes=0.25,
#                           resampleAlg=gdal.GRA_Average
#                          )
