# %%
import numpy as np
import pandas as pd
from osgeo import gdal
import matplotlib.pyplot as plt

# %%
data=gdal.Open('E://rahul/data/CREST-AMSR-E-Emissivity-Monthly-200207-V1.hdf')

# %%
data.GetSubDatasets()
# Out:
# [('HDF4_SDS:UNKNOWN:"E://rahul/data/CREST-AMSR-E-Emissivity-Monthly-200207-V1.hdf":0',
#   '[720x1440] 6.9  V (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"E://rahul/data/CREST-AMSR-E-Emissivity-Monthly-200207-V1.hdf":1',
#   '[720x1440] 6.9  H (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"E://rahul/data/CREST-AMSR-E-Emissivity-Monthly-200207-V1.hdf":2',
#   '[720x1440] 10.7 V (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"E://rahul/data/CREST-AMSR-E-Emissivity-Monthly-200207-V1.hdf":3',
#   '[720x1440] 10.7 H (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"E://rahul/data/CREST-AMSR-E-Emissivity-Monthly-200207-V1.hdf":4',
#   '[720x1440] 18.7 V (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"E://rahul/data/CREST-AMSR-E-Emissivity-Monthly-200207-V1.hdf":5',
#   '[720x1440] 18.7 H (64-bit floating-point)'),
#  ('HDF4_SDS:UNKNOWN:"E://rahul/data/CREST-AMSR-E-Emissivity-Monthly-200207-V1.hdf":6',
#   '[720x1440] 23.8 V (64-bit floating-point)'),
# ...

# %%
emis_18V=gdal.Open('HDF4_SDS:UNKNOWN:"E://rahul/data/CREST-AMSR-E-Emissivity-Monthly-200207-V1.hdf":4')

# %%
emis_18V=emis_18V.ReadAsArray()

# %%
plt.imshow(emis_18V)
